# %%
# %matplotlib inline
import pydtmc
import numpy as np

NUMBER_OF_NODES = 1024
R = 4

penMultiplierDisagreement = 1
nHoods = NUMBER_OF_NODES // R
#given equal stakes
#roundLength = ???
# 1/|neighbourhood| * 1/|n part of neighbourhood| 

expectedRewardPercentageHonest = (1/nHoods) * (1/R)

#one malicious user model

p_M = (1/nHoods) * (1/R)
p_H = (1/nHoods) * ((R-1)/R)


state = {
    0 : "unfrozen",
    1 : "othersfrozen",
    2 : "iamfrozen"
}
A = np.array([[0.0, 0.75, 0.25], [0.25, 0.75, 0.0], [0.25, 0.0, 0.75]])
A = np.array([[1-(p_M+p_H), p_M, p_H], [1/R,((R-1)/R), 0.0], [1/R, 0.0, ((R-1)/R)]])
# Out:
#   Cell In[39], line 28
#     A = np.array([[1-(p_M+p_H), p_M, p_H], [1/R,((R-1)/R), 0.0], [1/R, 0.0, ((R-1)/R]])
#                                                                                     ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
import scipy.linalg
values, left = scipy.linalg.eig(A, right = False, left = True)

print("left eigen vectors = \n", left, "\n")
print("eigen values = \n", values)
# Out:
# left eigen vectors =
#  [[-0.78446454  0.30151134  0.        ]
#  [ 0.58834841  0.90453403 -0.70710678]
#  [ 0.19611614  0.30151134  0.70710678]]
#
# eigen values =
#  [-0.25+0.j  1.  +0.j  0.75+0.j]

# %%
pi = left[:,1]
pi_normalized = [(x/np.sum(pi)).real for x in pi]
pi_normalized
# Out:
# [0.20000000000000012, 0.6, 0.19999999999999993]

# %%
#adjacency matrix 3x3
naiveP = [[1-(p_M+p_H), p_M, p_H], 
     [1/R,((R-1)/R), 0.0], 
     [1/R, 0.0, ((R-1)/R)]]

mc = pydtmc.MarkovChain(naiveP, ['unfrozen', 'mFrozen', 'hFrozen'])
print(mc)



print(mc.expected_rewards(10000,[0,1,1/3]))

unnormalised_rewards = mc.expected_rewards(10000,[1,1,1])
normalised_rewards = []
for k in unnormalised_rewards:
    high = sum(unnormalised_rewards)
    normalised_rewards.append(k/high)
print(normalised_rewards)

print(mc.mean_recurrence_times())
res =  mc.simulate(10000,initial_state="unfrozen", seed=32)

pydtmc.plot_graph(mc, dpi=150,force_standard=True)
# Out:
# DISCRETE-TIME MARKOV CHAIN
#  SIZE:           3
#  RANK:           3
#  CLASSES:        1
#   > RECURRENT:   1
#   > TRANSIENT:   0
#  ERGODIC:        YES
#   > APERIODIC:   YES
#   > IRREDUCIBLE: YES
#  ABSORBING:      NO
#  REGULAR:        YES
#  REVERSIBLE:     YES
#  SYMMETRIC:      NO
#
# [76.90047337 80.86970414 78.20303748]
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# [  1.015625   260.          86.66666667]

# %%
mc.states
# Out:
# ['unfrozen', 'mFrozen', 'hFrozen']

# %%
pydtmc.plot_eigenvalues(mc, dpi=150)
